# %%
import pandas as pd
from pathlib import Path

OUT = Path("outputs")

metrics = {
    "Validation": {"MAE": 0.1107, "RMSE": 0.1377, "R2": 0.9368},
    "Test": {"MAE": 0.1450, "RMSE": 0.1716, "R2": 0.8614}
}

# CSV olarak kaydet
df_metrics = pd.DataFrame(metrics).T
df_metrics.to_csv(OUT / "model_metrics.csv", index=True)

print("✅ Metrics saved successfully → outputs/model_metrics.csv")
df_metrics
# Out:
# ✅ Metrics saved successfully → outputs/model_metrics.csv
#                MAE    RMSE      R2
# Validation  0.1107  0.1377  0.9368
# Test        0.1450  0.1716  0.8614
